# %%
import numpy as np
from scipy.optimize import curve_fit
from matplotlib import pylab

from IPython.parallel import Client
rc = Client(profile='default')
# lbview = rc.load_balanced_view()
dview = rc.direct_view()

m2 = np.memmap("data.bin", dtype="float", shape=(1000, 10000))
def fun(x, a, b, c, d, e):
    return a*np.exp(-(x-b)**2/(2*c**2))+d*x+e

def funGaus(x, a, b, c):
    return a*np.exp(-(x-b)**2/(2*c**2))

def funTlo(x, d, e):
    return d*x+e

x = np.linspace(-40, 40, 10000)
y = m2[1]
popt, pcov = curve_fit(fun, x, y)
yFIT = funGaus(x, popt[0], popt[1], popt[2] )
yFITlo = funTlo(x, popt[3], popt[4])
pylab.plot(x, y)
pylab.plot(x, yFIT)
pylab.plot(x, yFITlo)
pylab.savefig('BOOM.png')

dview.scatter('m2', m2)
res = dview.pull('m2')
len(res)
dview.scatter('y', y)
dview.push({"x": x})
# Out:
# <AsyncResult: _push>

# %%
# %%px
# import numpy as np
# from scipy.optimize import curve_fit
# from matplotlib import pylab
#
# #m2 = np.memmap("data.bin", dtype="float", shape=(1000, 10000))
# def fun(x, a, b, c, d, e):
#     return a*np.exp(-(x-b)**2/(2*c**2))+d*x+e
#
# popt, pcov = curve_fit(fun, x, y)
# pylab.plot(x, y)
# Out:
# [0:execute]:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)<ipython-input-10-26170236a667> in <module>()
#       7     return a*np.exp(-(x-b)**2/(2*c**2))+d*x+e
#       8
# ----> 9 popt, pcov = curve_fit(fun, x, y)
#      10 pylab.plot(x, y)
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, **kw)
#     553     # Remove full_output from kw, otherwise we're passing it in twice.
#     554     return_full = kw.pop('full_output', False)
# --> 555     res = leastsq(func, p0, args=args, full_output=1, **kw)
#     556     (popt, pcov, infodict, errmsg, ier) = res
#     557
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     367     if not isinstance(args, tuple):
#     368         args = (args,)
# --> 369     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     370     m = shape[0]
#     371     if n > m:
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      18 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      19                 output_shape=None):
# ---> 20     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      21     if (output_shape is not None) and (shape(res) != output_shape):
#      22         if (output_shape[0] != 1):
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in _general_function(params, xdata, ydata, function)
#     443
#     444 def _general_function(params, xdata, ydata, function):
# --> 445     return function(xdata, *params) - ydata
#     446
#     447
# ValueError: operands could not be broadcast together with shapes (10000,) (2500,)
#
# [1:execute]:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)<ipython-input-10-26170236a667> in <module>()
#       7     return a*np.exp(-(x-b)**2/(2*c**2))+d*x+e
#       8
# ----> 9 popt, pcov = curve_fit(fun, x, y)
#      10 pylab.plot(x, y)
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, **kw)
#     553     # Remove full_output from kw, otherwise we're passing it in twice.
#     554     return_full = kw.pop('full_output', False)
# --> 555     res = leastsq(func, p0, args=args, full_output=1, **kw)
#     556     (popt, pcov, infodict, errmsg, ier) = res
#     557
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     367     if not isinstance(args, tuple):
#     368         args = (args,)
# --> 369     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     370     m = shape[0]
#     371     if n > m:
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      18 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      19                 output_shape=None):
# ---> 20     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      21     if (output_shape is not None) and (shape(res) != output_shape):
#      22         if (output_shape[0] != 1):
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in _general_function(params, xdata, ydata, function)
#     443
#     444 def _general_function(params, xdata, ydata, function):
# --> 445     return function(xdata, *params) - ydata
#     446
#     447
# ValueError: operands could not be broadcast together with shapes (10000,) (2500,)
#
# [2:execute]:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)<ipython-input-10-26170236a667> in <module>()
#       7     return a*np.exp(-(x-b)**2/(2*c**2))+d*x+e
#       8
# ----> 9 popt, pcov = curve_fit(fun, x, y)
#      10 pylab.plot(x, y)
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, **kw)
#     553     # Remove full_output from kw, otherwise we're passing it in twice.
#     554     return_full = kw.pop('full_output', False)
# --> 555     res = leastsq(func, p0, args=args, full_output=1, **kw)
#     556     (popt, pcov, infodict, errmsg, ier) = res
#     557
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     367     if not isinstance(args, tuple):
#     368         args = (args,)
# --> 369     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     370     m = shape[0]
#     371     if n > m:
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      18 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      19                 output_shape=None):
# ---> 20     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      21     if (output_shape is not None) and (shape(res) != output_shape):
#      22         if (output_shape[0] != 1):
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in _general_function(params, xdata, ydata, function)
#     443
#     444 def _general_function(params, xdata, ydata, function):
# --> 445     return function(xdata, *params) - ydata
#     446
#     447
# ValueError: operands could not be broadcast together with shapes (10000,) (2500,)
#
# [3:execute]:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)<ipython-input-10-26170236a667> in <module>()
#       7     return a*np.exp(-(x-b)**2/(2*c**2))+d*x+e
#       8
# ----> 9 popt, pcov = curve_fit(fun, x, y)
#      10 pylab.plot(x, y)
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, **kw)
#     553     # Remove full_output from kw, otherwise we're passing it in twice.
#     554     return_full = kw.pop('full_output', False)
# --> 555     res = leastsq(func, p0, args=args, full_output=1, **kw)
#     556     (popt, pcov, infodict, errmsg, ier) = res
#     557
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     367     if not isinstance(args, tuple):
#     368         args = (args,)
# --> 369     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     370     m = shape[0]
#     371     if n > m:
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      18 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      19                 output_shape=None):
# ---> 20     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      21     if (output_shape is not None) and (shape(res) != output_shape):
#      22         if (output_shape[0] != 1):
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/scipy/optimize/minpack.py in _general_function(params, xdata, ydata, function)
#     443
#     444 def _general_function(params, xdata, ydata, function):
# --> 445     return function(xdata, *params) - ydata
#     446
#     447
# ValueError: operands could not be broadcast together with shapes (10000,) (2500,)
