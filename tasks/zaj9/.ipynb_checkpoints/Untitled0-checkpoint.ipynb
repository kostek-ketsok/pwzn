# %%
import numpy as np
from scipy.optimize import curve_fit
from matplotlib import pylab

from IPython.parallel import Client
rc = Client(profile='default')
# lbview = rc.load_balanced_view()
dview = rc.direct_view()

m2 = np.memmap("data.bin", dtype="float", shape=(1000, 10000))
def fun(x, a, b, c, d, e):
    return a*np.exp(-(x-b)**2/(2*c**2))+d*x+e

def funGaus(x, a, b, c):
    return a*np.exp(-(x-b)**2/(2*c**2))

def funTlo(x, d, e):
    return d*x+e

x = np.linspace(-40, 40, 10000)
y = m2[1]
popt, pcov = curve_fit(fun, x, y)
yFIT = funGaus(x, popt[0], popt[1], popt[2] )
yFITlo = funTlo(x, popt[3], popt[4])
pylab.plot(x, y)
pylab.plot(x, yFIT)
pylab.plot(x, yFITlo)
pylab.savefig('BOOM.png')

dview.scatter('m2', m2)
res = dview.pull('m2')
len(res)
dview.scatter('y', y)
dview.push({"x": x})
# Out:
# <AsyncResult: _push>

# %%
# %%px
# import numpy as np
# from scipy.optimize import curve_fit
# from matplotlib import pylab
#
# m2 = np.memmap("data.bin", dtype="float", shape=(1000, 10000))
# def fun(x, a, b, c, d, e):
#     return a*np.exp(-(x-b)**2/(2*c**2))+d*x+e
#
# popt, pcov = curve_fit(fun, x, y)
# yFIT = funGaus(x, popt[0], popt[1], popt[2] )
# yFITlo = funTlo(x, popt[3], popt[4])
# pylab.plot(x, y)
# pylab.plot(x, yFIT)
# pylab.plot(x, yFITlo)
# Out:
# [0:execute]:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)<ipython-input-7-e43709dafb77> in <module>()
#       3 from matplotlib import pylab
#       4
# ----> 5 m2 = np.memmap("../data.bin", dtype="float", shape=(1000, 10000))
#       6 def fun(x, a, b, c, d, e):
#       7     return a*np.exp(-(x-b)**2/(2*c**2))+d*x+e
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/numpy/core/memmap.py in __new__(subtype, filename, dtype, mode, offset, shape, order)
#     212             own_file = False
#     213         else:
# --> 214             fid = open(filename, (mode == 'c' and 'r' or mode)+'b')
#     215             own_file = True
#     216
# FileNotFoundError: [Errno 2] No such file or directory: '../data.bin'
#
# [1:execute]:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)<ipython-input-7-e43709dafb77> in <module>()
#       3 from matplotlib import pylab
#       4
# ----> 5 m2 = np.memmap("../data.bin", dtype="float", shape=(1000, 10000))
#       6 def fun(x, a, b, c, d, e):
#       7     return a*np.exp(-(x-b)**2/(2*c**2))+d*x+e
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/numpy/core/memmap.py in __new__(subtype, filename, dtype, mode, offset, shape, order)
#     212             own_file = False
#     213         else:
# --> 214             fid = open(filename, (mode == 'c' and 'r' or mode)+'b')
#     215             own_file = True
#     216
# FileNotFoundError: [Errno 2] No such file or directory: '../data.bin'
#
# [2:execute]:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)<ipython-input-7-e43709dafb77> in <module>()
#       3 from matplotlib import pylab
#       4
# ----> 5 m2 = np.memmap("../data.bin", dtype="float", shape=(1000, 10000))
#       6 def fun(x, a, b, c, d, e):
#       7     return a*np.exp(-(x-b)**2/(2*c**2))+d*x+e
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/numpy/core/memmap.py in __new__(subtype, filename, dtype, mode, offset, shape, order)
#     212             own_file = False
#     213         else:
# --> 214             fid = open(filename, (mode == 'c' and 'r' or mode)+'b')
#     215             own_file = True
#     216
# FileNotFoundError: [Errno 2] No such file or directory: '../data.bin'
#
# [3:execute]:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)<ipython-input-7-e43709dafb77> in <module>()
#       3 from matplotlib import pylab
#       4
# ----> 5 m2 = np.memmap("../data.bin", dtype="float", shape=(1000, 10000))
#       6 def fun(x, a, b, c, d, e):
#       7     return a*np.exp(-(x-b)**2/(2*c**2))+d*x+e
# /home/pwzn/Desktop/diadaw/jakkolwiek/lib/python3.4/site-packages/numpy/core/memmap.py in __new__(subtype, filename, dtype, mode, offset, shape, order)
#     212             own_file = False
#     213         else:
# --> 214             fid = open(filename, (mode == 'c' and 'r' or mode)+'b')
#     215             own_file = True
#     216
# FileNotFoundError: [Errno 2] No such file or directory: '../data.bin'
